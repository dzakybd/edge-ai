# %% [markdown]
# # Load libraries & parameters

# %%
# %matplotlib inline
import itertools as it
from sklearn.impute import SimpleImputer, KNNImputer
import numpy as np 
import pandas as pd 
import math
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.utils import to_categorical
from keras.utils import np_utils
import seaborn as sns
import scipy.cluster.hierarchy as spc
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from jmetal.algorithm.singleobjective.genetic_algorithm import GeneticAlgorithm
from jmetal.operator import BitFlipMutation, SPXCrossover, BinaryTournamentSelection
from jmetal.util.termination_criterion import StoppingByEvaluations
from jmetal.util.observer import PrintObjectivesObserver
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import datetime
import pickle
from sklearn.metrics import confusion_matrix
from keras.models import load_model
from sklearn import preprocessing
from keras.utils import plot_model
from imblearn.over_sampling import SMOTE
from collections import Counter
from jmetal.core.problem import BinaryProblem
from jmetal.core.solution import BinarySolution
import random
from pyearth import Earth
# Out:
# Using TensorFlow backend.

# %%
# parameter
n_neighbors = 3
null_percentage = 0.1
test_ratio = 0.2
random_state = 1
weights = [1/3, 1/3, 1/3]

load_saved_data = False
load_saved_model = False

# 0 CLFS
# 1 CFS
# 2 PCA
feature_selection = 0

# %% [markdown]
# # Load dataset

# %%
#  reading the data
data_ori = pd.read_csv('uci-secom.csv')
data_ori = data_ori.drop(['Time'], axis = 1)
data_ori.loc[data_ori['Fault'] == 1, 'Fault'] = 1
data_ori.loc[data_ori['Fault'] == -1, 'Fault'] = 0

# getting the shape of the data
print(data_ori.shape)
# Out:
# (1567, 591)

# %%
output_labels = data_ori['Fault'].value_counts()
fault_fraction = output_labels[1]/float(output_labels[0])
n_all_data = len(data_ori)
n_pass_data = output_labels[0]
n_fail_data = output_labels[1]
print('fault_fraction', fault_fraction)
print('total data', n_all_data)
print('pass data', n_pass_data)
print('fail data', n_fail_data)
# Out:
# fault_fraction 0.0710868079289132
# total data 1567
# pass data 1463
# fail data 104

# %%
data_ori.head()

# %%
data_ori.describe()

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Data cleaning

# %%
def drop_constant_column(dataframe):
    for column in dataframe.columns:
        unique = dataframe[column].unique()
        unique = unique[~np.isnan(unique)]
        if len(unique) == 1:
            dataframe.drop(column,inplace=True,axis=1)
    return dataframe

if not load_saved_data:
    # Drop columns with constant value
    data_clean = drop_constant_column(data_ori)

    # Only keep columns with NaN values below percentage
    data_clean = data_clean.loc[:, data_clean.isnull().mean() < null_percentage]

    # print precentage of NaN value in each coloumn
    print(data_clean.isnull().mean())

    data_clean.head()

# %% [markdown]
# ## Data imputation

# %%
if not load_saved_data:
    # data.replace(np.nan, 0, inplace = True)
    # imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
    imputer = KNNImputer(n_neighbors=n_neighbors)
    imputer.fit(data_clean)
    data_impu = pd.DataFrame(imputer.transform(data_clean), columns=data_clean.columns)

    print("Is there any null?", data_impu.isnull().any().any())

# %% [markdown]
# ## Data normalization

# %%
def normalize_data(data):
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(data.values)
    data_norm = pd.DataFrame(x_scaled, columns=data.columns, index=data.index)
    return data_norm

if not load_saved_data:
    data_norm = normalize_data(data_impu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4fbd4f3f6c83> in <module>
#       6
#       7 if not load_saved_data:
# ----> 8     data_norm = normalize_data(data_impu)
#
# NameError: name 'data_impu' is not defined

# %%
if not load_saved_data:
    data_prepro = data_norm
    data_prepro.to_pickle('data_preprocessed.pkl')
else:
    data_prepro = pd.read_pickle('data_preprocessed.pkl')

x_all = data_prepro.iloc[:, :-1]
y_all = data_prepro.iloc[:, -1]

# %% [markdown]
# ## Data sampling (optional)

# %%
if not load_saved_data:
    sm = SMOTE(random_state=1)
    x_sample, y_sample = sm.fit_resample(x_all, y_all)
    print('Resampled dataset shape %s' % Counter(y_sample))

# %% [markdown]
# ## Dataset splitting

# %%
if not load_saved_data:
    data_prepro_sample = pd.concat([x_sample, y_sample], axis=1)
    data_prepro_sample.to_pickle('data_prepro_sample.pkl')
else:
    data_prepro_sample = pd.read_pickle('data_prepro_sample.pkl')
    x_sample = data_prepro_sample.iloc[:, :-1]
    y_sample = data_prepro_sample.iloc[:, -1]

# %%
data_prepro_sample['Fault'].value_counts()
# Out:
# 1.0    1463
# 0.0    1463
# Name: Fault, dtype: int64

# %%
x_train_sample, x_test_sample, y_train_sample, y_test_sample = train_test_split(x_sample, y_sample, test_size=test_ratio, random_state=random_state)

# %% [markdown]
# # Correlation & Latency aware Feature Selection

# %% [markdown]
# ## Get correlation coefficient

# %%
def correlation_function(corrmat, title):    
    # Get correlations of each features in dataset
    # Range 0-1
    all_correlation = corrmat.values
    feat_to_feat_corr = corrmat.iloc[:-1, :-1]
    feat_to_label_corr = corrmat.iloc[:-1, -1]
    
    # plot only top 100
    fig = feat_to_label_corr.nlargest(100).plot(kind='barh', figsize=(20, 20)).get_figure()
    fig.show()

    if not load_saved_data:
        fig.savefig('feat_to_label_corr_{}.png'.format(title))
        
    #plot heat map
    plt.figure(figsize=(20,20))
    # tick labelnya lompat2 biar muat
    g=sns.heatmap(feat_to_feat_corr, vmin=0, vmax=1,cmap="RdYlGn")

    if not load_saved_data:
        plt.savefig('feat_to_feat_corr_{}.png'.format(title))

# %%
corrmat = abs(data_prepro.corr())
correlation_function(corrmat, 'prepro')
# Out:
# C:\Users\HANSUNG\.conda\envs\HAR\lib\site-packages\ipykernel_launcher.py:10: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Get latency scale

# %%
# all_latency = np.ones(len(data_prepro.columns))
# all_latency = pd.DataFrame(all_latency.reshape(1, -1), columns=data_prepro.columns)

def load_latency_data(title):
    latency_data = pd.read_csv(title)
    latency_data = latency_data.drop(['Column'], axis = 1)
    return latency_data
    
edge_latency = load_latency_data('edge_latency.csv')
scaled_edge_latency = normalize_data(edge_latency)

cloud_latency = load_latency_data('cloud_latency.csv')
scaled_cloud_latency = normalize_data(cloud_latency)

# %%
edge_latency.head()
# Out:
#    Latency
# 0    6.010
# 1    2.966
# 2    5.988
# 3    8.987
# 4    6.967

# %%
scaled_edge_latency.head()
# Out:
#     Latency
# 0  0.455727
# 1  0.179000
# 2  0.453727
# 3  0.726364
# 4  0.542727

# %% [markdown]
# ## Genetic algorithm

# %%
# Feature correlation selection
class CLFS(BinaryProblem):

    def __init__(self, correlation, latency, features, weights):
        super(CLFS, self).__init__()

        self.correlation = correlation
        self.latency = latency
        self.features = features
        self.weights = weights
        self.number_of_bits = len(features)
        
        # Minimization to find most independent between variable 
        self.obj_directions = [self.MINIMIZE]
        self.number_of_variables = 1
        self.number_of_objectives = 1
        self.number_of_constraints = 0

    def evaluate(self, solution: BinarySolution) -> BinarySolution:
        
        # List selected features
        feats = []
        for idx, bits in enumerate(solution.variables[0]):
            if bits:
                feats.append(str(self.features[idx]))
                
        # calculate label correlation
        label_corr = 0
        for j in feats:
            label_corr += (1-self.correlation[j][-1])
        label_corr = label_corr/len(feats)

        # calculate feature correlation
        feat_corr = 0
        comb = list(it.combinations(feats, 2))
        for j in comb:
            feat_corr += self.correlation[j[0]][j[1]]
        feat_corr = feat_corr/len(comb)
        
        if feature_selection==0:
            # calculate latency scale
            latency_scale = 0
            for j in feats:
                latency_scale += float(self.latency.iloc[int(j)])
            latency_scale = latency_scale/len(feats)

        if feature_selection==0:
            fitness = (weights[0]*label_corr) + (weights[1]*feat_corr) + (weights[2]*latency_scale)
        else:
            fitness = (label_corr/2) + (feat_corr/2)
        
        solution.objectives[0] = fitness

        return solution

    def create_solution(self) -> BinarySolution:
        new_solution = BinarySolution(number_of_variables=self.number_of_variables, number_of_objectives=self.number_of_objectives)
        new_solution.variables[0] = [True if random.randint(0, 1) == 1 else False for _ in range(self.number_of_bits)]
        return new_solution
    
    def get_name(self):
        return 'Correlation-Latency aware Feature Selection'

# %%
def clfs_ga(corrmat, scaled_latency, features, weights, title):
    problem = CLFS(corrmat, scaled_latency, features, weights)

    algorithm = GeneticAlgorithm(
            problem=problem,
            population_size=100,
            offspring_population_size=100,
            mutation=BitFlipMutation(1.0 / problem.number_of_bits),
            crossover=SPXCrossover(0.8),
            selection=BinaryTournamentSelection(),
            termination_criterion=StoppingByEvaluations(max=10000)
        )

    algorithm.observable.register(observer=PrintObjectivesObserver())

    algorithm.run()
    result = algorithm.get_result()

    variables = x_all.columns[result.variables[0]]
    
    info = '\nAlgorithm: {}'.format(algorithm.get_name())
    info += '\nProblem: CLFS using {} latency'.format(title)
    info += '\nNumber of features: {}'.format(len(variables))
    info += '\nFitness: {}'.format(result.objectives[0])
    info += '\nComputing time: {}'.format(algorithm.total_computing_time)
    print(info)
    
    if not load_saved_data:    
        f = open('ga_info_{}.txt'.format(title), 'w')
        f.write(info)
    
    return variables

# %% [markdown]
# ## Execute on Feature selection on Edge

# %%
from sklearn.decomposition import PCA
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier

if feature_selection==0:
    print('Use latency')
    if not load_saved_data:
        variables_edge = clfs_ga(corrmat, scaled_edge_latency, x_all.columns, weights, 'edge_clfs')
        with open('variables_edge_clfs.pkl', 'wb') as filename:
            pickle.dump(variables_edge, filename) 
    else:
        with open('variables_edge_clfs.pkl', 'rb') as pickle_file:
            variables_edge = pickle.load(pickle_file)
elif feature_selection==1: 
    print('Didnt use latency')
    if not load_saved_data:
        variables_edge = clfs_ga(corrmat, scaled_edge_latency, x_all.columns, weights, 'edge_cfs')
        with open('variables_edge_cfs.pkl', 'wb') as filename:
            pickle.dump(variables_edge, filename) 
    else:
        with open('variables_edge_cfs.pkl', 'rb') as pickle_file:
            variables_edge = pickle.load(pickle_file)
elif feature_selection==2:
    print('Use PCA')
    if not load_saved_data:
        # pca - keep 90% of variance
        pca = PCA(0.90)
        principal_components = pca.fit_transform(x_all)
#         principal_df = pd.DataFrame(data = principal_components)
        print(principal_components.shape)
        with open('variables_edge_pca.pkl', 'wb') as filename:
            pickle.dump(variables_edge, filename) 
    else:
        with open('variables_edge_pca.pkl', 'rb') as pickle_file:
            variables_edge = pickle.load(pickle_file)
# Out:
# Use latency
# 2020-02-14 01:26:31,320 [MainThread  ] [INFO ]  Evaluations: 100. fitness: [0.4220944340724809]
# 2020-02-14 01:26:53,988 [MainThread  ] [INFO ]  Evaluations: 200. fitness: [0.41032453514325523]
# 2020-02-14 01:27:16,525 [MainThread  ] [INFO ]  Evaluations: 300. fitness: [0.40948901758672046]
# 2020-02-14 01:27:39,266 [MainThread  ] [INFO ]  Evaluations: 400. fitness: [0.4084585560998776]
# 2020-02-14 01:28:02,417 [MainThread  ] [INFO ]  Evaluations: 500. fitness: [0.4078778680756094]
# 2020-02-14 01:28:25,607 [MainThread  ] [INFO ]  Evaluations: 600. fitness: [0.4073619345117076]
# 2020-02-14 01:28:49,156 [MainThread  ] [INFO ]  Evaluations: 700. fitness: [0.40651382901444344]
# 2020-02-14 01:29:13,259 [MainThread  ] [INFO ]  Evaluations: 800. fitness: [0.4047220661900468]
# 2020-02-14 01:29:36,248 [MainThread  ] [INFO ]  Evaluations: 900. fitness: [0.4047220661900468]
# 2020-02-14 01:29:59,062 [MainThread  ] [INFO ]  Evaluations: 1000. fitness: [0.403368672012462]
# 2020-02-14 01:30:21,643 [MainThread  ] [INFO ]  Evaluations: 1100. fitness: [0.40192107457931947]
# 2020-02-14 01:30:44,234 [MainThread  ] [INFO ]  Evaluations: 1200. fitness: [0.4015518371220307]
# 2020-02-14 01:31:06,175 [MainThread  ] [INFO ]  Evaluations: 1300. fitness: [0.4013269602093875]
# 2020-02-14 01:31:27,760 [MainThread  ] [INFO ]  Evaluations: 1400. fitness: [0.40026222967942726]
# 2020-02-14 01:31:49,449 [MainThread  ] [INFO ]  Evaluations: 1500. fitness: [0.40026222967942726]
# 2020-02-14 01:32:10,581 [MainThread  ] [INFO ]  Evaluations: 1600. fitness: [0.39931122105955474]
# 2020-02-14 01:32:32,057 [MainThread  ] [INFO ]  Evaluations: 1700. fitness: [0.39931122105955474]
# 2020-02-14 01:32:53,411 [MainThread  ] [INFO ]  Evaluations: 1800. fitness: [0.3982329955552003]
# 2020-02-14 01:33:14,798 [MainThread  ] [INFO ]  Evaluations: 1900. fitness: [0.3982329955552003]
# 2020-02-14 01:33:36,077 [MainThread  ] [INFO ]  Evaluations: 2000. fitness: [0.39802857140473935]
# 2020-02-14 01:33:57,048 [MainThread  ] [INFO ]  Evaluations: 2100. fitness: [0.39774907803597304]
# 2020-02-14 01:34:17,668 [MainThread  ] [INFO ]  Evaluations: 2200. fitness: [0.39753129852308017]
# 2020-02-14 01:34:38,344 [MainThread  ] [INFO ]  Evaluations: 2300. fitness: [0.3972985391619609]
# 2020-02-14 01:34:58,815 [MainThread  ] [INFO ]  Evaluations: 2400. fitness: [0.3968512282368661]
# 2020-02-14 01:35:19,240 [MainThread  ] [INFO ]  Evaluations: 2500. fitness: [0.39655794334591504]
# 2020-02-14 01:35:39,283 [MainThread  ] [INFO ]  Evaluations: 2600. fitness: [0.3952689389236404]
# 2020-02-14 01:35:59,253 [MainThread  ] [INFO ]  Evaluations: 2700. fitness: [0.3950820108103904]
# 2020-02-14 01:36:19,114 [MainThread  ] [INFO ]  Evaluations: 2800. fitness: [0.3948549389622107]
# 2020-02-14 01:36:38,903 [MainThread  ] [INFO ]  Evaluations: 2900. fitness: [0.3943302618408591]
# 2020-02-14 01:36:58,173 [MainThread  ] [INFO ]  Evaluations: 3000. fitness: [0.3943302618408591]
# 2020-02-14 01:37:17,407 [MainThread  ] [INFO ]  Evaluations: 3100. fitness: [0.3935203423881719]
# 2020-02-14 01:37:36,643 [MainThread  ] [INFO ]  Evaluations: 3200. fitness: [0.3935203423881719]
# 2020-02-14 01:37:55,414 [MainThread  ] [INFO ]  Evaluations: 3300. fitness: [0.3928915612282501]
# 2020-02-14 01:38:13,985 [MainThread  ] [INFO ]  Evaluations: 3400. fitness: [0.3923473441391758]
# 2020-02-14 01:38:32,175 [MainThread  ] [INFO ]  Evaluations: 3500. fitness: [0.39196094466698994]
# 2020-02-14 01:38:50,659 [MainThread  ] [INFO ]  Evaluations: 3600. fitness: [0.39191011217573424]
# 2020-02-14 01:39:08,898 [MainThread  ] [INFO ]  Evaluations: 3700. fitness: [0.39175318664613634]
# 2020-02-14 01:39:27,236 [MainThread  ] [INFO ]  Evaluations: 3800. fitness: [0.39157878054717105]
# 2020-02-14 01:39:45,137 [MainThread  ] [INFO ]  Evaluations: 3900. fitness: [0.39076019007756596]
# 2020-02-14 01:40:02,950 [MainThread  ] [INFO ]  Evaluations: 4000. fitness: [0.39076019007756596]
# 2020-02-14 01:40:20,729 [MainThread  ] [INFO ]  Evaluations: 4100. fitness: [0.3905922716971221]
# 2020-02-14 01:40:38,201 [MainThread  ] [INFO ]  Evaluations: 4200. fitness: [0.3899007843982142]
# 2020-02-14 01:40:55,406 [MainThread  ] [INFO ]  Evaluations: 4300. fitness: [0.3898180464442259]
# 2020-02-14 01:41:12,602 [MainThread  ] [INFO ]  Evaluations: 4400. fitness: [0.3895900305288613]
# 2020-02-14 01:41:29,315 [MainThread  ] [INFO ]  Evaluations: 4500. fitness: [0.3892826369904961]
# 2020-02-14 01:41:45,874 [MainThread  ] [INFO ]  Evaluations: 4600. fitness: [0.3888439014089931]
# 2020-02-14 01:42:01,888 [MainThread  ] [INFO ]  Evaluations: 4700. fitness: [0.3888439014089931]
# 2020-02-14 01:42:17,873 [MainThread  ] [INFO ]  Evaluations: 4800. fitness: [0.3887395597809725]
# 2020-02-14 01:42:33,924 [MainThread  ] [INFO ]  Evaluations: 4900. fitness: [0.38809234278692334]
# 2020-02-14 01:42:49,889 [MainThread  ] [INFO ]  Evaluations: 5000. fitness: [0.38775539803249065]
# 2020-02-14 01:43:05,642 [MainThread  ] [INFO ]  Evaluations: 5100. fitness: [0.387601688785326]
# 2020-02-14 01:43:21,488 [MainThread  ] [INFO ]  Evaluations: 5200. fitness: [0.38723385592221377]
# 2020-02-14 01:43:37,210 [MainThread  ] [INFO ]  Evaluations: 5300. fitness: [0.38711328416721086]
# 2020-02-14 01:43:52,812 [MainThread  ] [INFO ]  Evaluations: 5400. fitness: [0.3868067936968607]
# 2020-02-14 01:44:08,341 [MainThread  ] [INFO ]  Evaluations: 5500. fitness: [0.3868067936968607]
# 2020-02-14 01:44:23,846 [MainThread  ] [INFO ]  Evaluations: 5600. fitness: [0.38610453849375886]
# 2020-02-14 01:44:39,400 [MainThread  ] [INFO ]  Evaluations: 5700. fitness: [0.38610453849375886]
# 2020-02-14 01:44:55,044 [MainThread  ] [INFO ]  Evaluations: 5800. fitness: [0.38610453849375886]
# 2020-02-14 01:45:10,506 [MainThread  ] [INFO ]  Evaluations: 5900. fitness: [0.3860027558347345]
# 2020-02-14 01:45:26,094 [MainThread  ] [INFO ]  Evaluations: 6000. fitness: [0.38585037189070304]
# 2020-02-14 01:45:41,632 [MainThread  ] [INFO ]  Evaluations: 6100. fitness: [0.3851067174110993]
# 2020-02-14 01:45:57,154 [MainThread  ] [INFO ]  Evaluations: 6200. fitness: [0.3851067174110993]
# 2020-02-14 01:46:12,651 [MainThread  ] [INFO ]  Evaluations: 6300. fitness: [0.38453278412251884]
# 2020-02-14 01:46:27,997 [MainThread  ] [INFO ]  Evaluations: 6400. fitness: [0.38400035734178695]
# 2020-02-14 01:46:43,589 [MainThread  ] [INFO ]  Evaluations: 6500. fitness: [0.3837383862460776]
# 2020-02-14 01:47:00,925 [MainThread  ] [INFO ]  Evaluations: 6600. fitness: [0.3835398379314362]
# 2020-02-14 01:47:18,257 [MainThread  ] [INFO ]  Evaluations: 6700. fitness: [0.3834307590415309]
# 2020-02-14 01:47:34,814 [MainThread  ] [INFO ]  Evaluations: 6800. fitness: [0.3832944619242259]
# 2020-02-14 01:47:50,302 [MainThread  ] [INFO ]  Evaluations: 6900. fitness: [0.38309914870789025]
# 2020-02-14 01:48:05,748 [MainThread  ] [INFO ]  Evaluations: 7000. fitness: [0.3829453347135873]
# 2020-02-14 01:48:20,940 [MainThread  ] [INFO ]  Evaluations: 7100. fitness: [0.38257054500029875]
# 2020-02-14 01:48:36,223 [MainThread  ] [INFO ]  Evaluations: 7200. fitness: [0.3822248788360448]
# 2020-02-14 01:48:51,454 [MainThread  ] [INFO ]  Evaluations: 7300. fitness: [0.3822248788360448]
# 2020-02-14 01:49:06,524 [MainThread  ] [INFO ]  Evaluations: 7400. fitness: [0.38191412215847265]
# 2020-02-14 01:49:21,284 [MainThread  ] [INFO ]  Evaluations: 7500. fitness: [0.38191412215847265]
# 2020-02-14 01:49:35,896 [MainThread  ] [INFO ]  Evaluations: 7600. fitness: [0.38176961664475745]
# 2020-02-14 01:49:50,237 [MainThread  ] [INFO ]  Evaluations: 7700. fitness: [0.38176961664475745]
# 2020-02-14 01:50:04,248 [MainThread  ] [INFO ]  Evaluations: 7800. fitness: [0.38143812696031393]
# 2020-02-14 01:50:17,973 [MainThread  ] [INFO ]  Evaluations: 7900. fitness: [0.3812727277540768]
# 2020-02-14 01:50:31,692 [MainThread  ] [INFO ]  Evaluations: 8000. fitness: [0.38114320141077895]
# 2020-02-14 01:50:45,285 [MainThread  ] [INFO ]  Evaluations: 8100. fitness: [0.38096598998738107]
# 2020-02-14 01:50:58,715 [MainThread  ] [INFO ]  Evaluations: 8200. fitness: [0.3809203910884451]
# 2020-02-14 01:51:12,003 [MainThread  ] [INFO ]  Evaluations: 8300. fitness: [0.38048209684817674]
# 2020-02-14 01:51:25,176 [MainThread  ] [INFO ]  Evaluations: 8400. fitness: [0.38048209684817674]
# 2020-02-14 01:51:38,291 [MainThread  ] [INFO ]  Evaluations: 8500. fitness: [0.38048209684817674]
# 2020-02-14 01:51:51,273 [MainThread  ] [INFO ]  Evaluations: 8600. fitness: [0.38048209684817674]
# 2020-02-14 01:52:04,240 [MainThread  ] [INFO ]  Evaluations: 8700. fitness: [0.380200903820351]
# 2020-02-14 01:52:17,172 [MainThread  ] [INFO ]  Evaluations: 8800. fitness: [0.3799294511202723]
# 2020-02-14 01:52:29,968 [MainThread  ] [INFO ]  Evaluations: 8900. fitness: [0.37970790409761873]
# 2020-02-14 01:52:42,875 [MainThread  ] [INFO ]  Evaluations: 9000. fitness: [0.37938698472831706]
# 2020-02-14 01:52:55,713 [MainThread  ] [INFO ]  Evaluations: 9100. fitness: [0.37938698472831706]
# 2020-02-14 01:53:08,474 [MainThread  ] [INFO ]  Evaluations: 9200. fitness: [0.3792710156393987]
# 2020-02-14 01:53:21,133 [MainThread  ] [INFO ]  Evaluations: 9300. fitness: [0.3791076914778446]
# 2020-02-14 01:53:33,815 [MainThread  ] [INFO ]  Evaluations: 9400. fitness: [0.3786436856324286]
# 2020-02-14 01:53:46,402 [MainThread  ] [INFO ]  Evaluations: 9500. fitness: [0.37857969353484466]
# 2020-02-14 01:53:58,895 [MainThread  ] [INFO ]  Evaluations: 9600. fitness: [0.3784059296917452]
# 2020-02-14 01:54:11,371 [MainThread  ] [INFO ]  Evaluations: 9700. fitness: [0.3781572869179655]
# 2020-02-14 01:54:23,757 [MainThread  ] [INFO ]  Evaluations: 9800. fitness: [0.37807064206167795]
# 2020-02-14 01:54:36,171 [MainThread  ] [INFO ]  Evaluations: 9900. fitness: [0.37799372120962116]
# 2020-02-14 01:54:48,624 [MainThread  ] [INFO ]  Evaluations: 10000. fitness: [0.3777554203695245]
# Algorithm: Genetic algorithm
# Problem: CLFS using edge_clfs latency
# Number of features: 148
# Fitness: 0.3777554203695245
# Computing time: 1719.767786026001

# %%
variables_edge
# Out:
# Int64Index([305, 211, 396, 110,  29, 107, 367, 115, 394, 303,
#             ...
#             356, 415, 417, 348, 197, 341, 268, 295, 358, 259],
#            dtype='int64', length=250)

# %%
sel_variables_edge = [str(i) for i in variables_edge]
sel_variables_edge.append('Fault')
sel_data_edge = data_prepro.loc[:, sel_variables_edge]

sel_corrmat_edge = abs(sel_data_edge.corr())
correlation_function(sel_corrmat_edge, 'sel_edge')
# Out:
# C:\Users\HANSUNG\.conda\envs\HAR\lib\site-packages\pandas\core\indexing.py:1418: FutureWarning:
#
#
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#
# C:\Users\HANSUNG\.conda\envs\HAR\lib\site-packages\ipykernel_launcher.py:10: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Execute on CLFS Cloud

# %%
if not load_saved_data:
    variables_cloud = clfs_ga(corrmat, scaled_cloud_latency, x_all.columns, weights, 'cloud')
    with open('variables_cloud.pkl', 'wb') as filename:
        pickle.dump(variables_cloud, filename)
else:
    with open('variables_cloud.pkl', 'rb') as pickle_file:
        variables_cloud = pickle.load(pickle_file)

# %%
sel_variables_cloud = [str(i) for i in variables_cloud]
sel_variables_cloud.append('Fault')
sel_data_cloud = data_prepro.loc[:, sel_variables_cloud]

sel_corrmat_cloud = abs(sel_data_cloud.corr())
correlation_function(sel_corrmat_cloud, 'sel_cloud')

# %% [markdown]
# # Training & Test

# %%
def test_model(clf, x, y, title):
    print('Test on {}'.format(title))
    labels = ['Pass', 'Fail']
    if 'all' in title or 'edge' in title or 'cloud' in title:
        y_pred = clf.predict_classes(x)
    else:
        y_pred = clf.predict(x)
    
    # Confusion matrix and classification report
    matrix = confusion_matrix(y, y_pred)
    g=sns.heatmap(matrix,annot=True,cbar=False, fmt='g', xticklabels=labels, yticklabels=labels)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.title('Confusion matrix of {}'.format(title))
    if not load_saved_model:
        plt.savefig('conmatrix-{}.png'.format(title))
    plt.show()
    
    counts = y.value_counts()
    print(counts)
    info = 'Scenario : {}\n'.format(title)
    if 'test' in title:
        info += 'Pass/Fail : {}/{}\n'.format(counts[0], counts[1])
    else:
        info += 'Pass : {}\n'.format(counts[0])    
    info += classification_report(y, y_pred, target_names=labels)
    print(info)
    if not load_saved_model:
        f = open('test-{}.txt'.format(title), 'w')
        f.write(info)
    
    plt.close()

def train_model(x, y, title):
    clf = Sequential()
    clf.add(Dense(64, input_dim=x.shape[1], activation='relu'))
    clf.add(Dense(32, activation='relu'))
    clf.add(Dense(1, activation='sigmoid'))
    clf.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    print(clf.summary())
    
    clf.fit(x, y, epochs=100)
    
    if not load_saved_model:
        plot_model(clf, to_file='model_{}.png'.format(title))
        clf.save('model_{}.h5'.format(title))
    
    return clf

# %% [markdown]
# ## Model - all features

# %%
x_train_sample.shape
# Out:
# (2340, 422)

# %%
title = 'all'
if not load_saved_model:
    clf_all = train_model(x_train_sample, y_train_sample, title)
else:
    clf_all = load_model('model_{}.h5'.format(title))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 64)                1984
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 4,097
# Trainable params: 4,097
# Non-trainable params: 0
# _________________________________________________________________
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-77767bd6e971> in <module>
#       1 title = 'all'
#       2 if not load_saved_model:
# ----> 3     clf_all = train_model(k_features, y_train_sample, title)
#       4 else:
#       5     clf_all = load_model('model_{}.h5'.format(title))
#
# <ipython-input-63-fb9ce0c90b28> in train_model(x, y, title)
#      41     print(clf.summary())
#      42
# ---> 43     clf.fit(x, y, epochs=100)
#      44
#      45     if not load_saved_model:
#
# ~\.conda\envs\HAR\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1152             sample_weight=sample_weight,
#    1153             class_weight=class_weight,
# -> 1154             batch_size=batch_size)
#    1155
#    1156         # Prepare validation data.
#
# ~\.conda\envs\HAR\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     635             # Check that all arrays have the same length.
#     636             if check_array_lengths:
# --> 637                 training_utils.check_array_length_consistency(x, y, sample_weights)
#     638             if self._is_graph_network:
#     639                 # Additional checks to avoid users mistakenly
#
# ~\.conda\envs\HAR\lib\site-packages\keras\engine\training_utils.py in check_array_length_consistency(inputs, targets, weights)
#     242                          'the same number of samples as target arrays. '
#     243                          'Found ' + str(list(set_x)[0]) + ' input samples '
# --> 244                          'and ' + str(list(set_y)[0]) + ' target samples.')
#     245     if len(set_w) > 1:
#     246         raise ValueError('All sample_weight arrays should have '
#
# ValueError: Input arrays should have the same number of samples as target arrays. Found 2926 input samples and 2340 target samples.

# %%
test_model(clf_all, x_train_sample, y_train_sample, 'train_all')

# %%
test_model(clf_all, x_test_sample, y_test_sample, 'test_all')

# %% [markdown]
# ## NN - CLFS cloud

# %%
x_train_sel_cloud = x_train_sample.loc[:, variables_cloud]
x_test_sel_cloud = x_test_sample.loc[:, variables_cloud]
x_train_sel_cloud.shape

# %%
title = 'cloud'
if not load_saved_model:
    clf_cloud = train_model(x_train_sel_cloud, y_train_sample, title)
else:
    clf_cloud = load_model('model_{}.h5'.format(title))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-6fa871bf60c2> in <module>
#       1 title = 'cloud'
#       2 if not load_saved_model:
# ----> 3     clf_cloud = train_model(x_train_sel_cloud, y_train_sample, title)
#       4 else:
#       5     clf_cloud = load_model('model_{}.h5'.format(title))
#
# NameError: name 'x_train_sel_cloud' is not defined

# %%
test_model(clf_cloud, x_train_sel_cloud, y_train_sample, 'train_cloud')

# %%
test_model(clf_cloud, x_test_sel_cloud, y_test_sample, 'test_cloud')

# %% [markdown]
# ## NN - CLFS edge

# %%
x_train_sel_edge = x_train_sample.iloc[:, variables_edge]
x_test_sel_edge = x_test_sample.iloc[:, variables_edge]
x_train_sel_edge.shape
# Out:
# (2340, 250)

# %%
x_train_sample, x_test_sample, y_train_sample, y_test_sample = train_test_split(k_features, y_sample, test_size=test_ratio, random_state=random_state)

# %%
x_test_sample.shape
# Out:
# (586, 30)

# %%
title = 'edge'
if not load_saved_model:
    clf_edge = train_model(x_train_sample, y_train_sample, title)
else:
    clf_edge = load_model('model_{}.h5'.format(title))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 64)                1984
# _________________________________________________________________
# dense_29 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 4,097
# Trainable params: 4,097
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 2340/2340 [==============================] - 1s 274us/step - loss: 0.6921 - accuracy: 0.5085
# Epoch 2/100
# 2340/2340 [==============================] - 0s 100us/step - loss: 0.6809 - accuracy: 0.5756
# Epoch 3/100
# 2340/2340 [==============================] - 0s 120us/step - loss: 0.6672 - accuracy: 0.6175
# Epoch 4/100
# 2340/2340 [==============================] - 0s 104us/step - loss: 0.6467 - accuracy: 0.6432
# Epoch 5/100
# 2340/2340 [==============================] - 0s 124us/step - loss: 0.6222 - accuracy: 0.6607
# Epoch 6/100
# 2340/2340 [==============================] - 0s 119us/step - loss: 0.6055 - accuracy: 0.6821
# Epoch 7/100
# 2340/2340 [==============================] - 0s 118us/step - loss: 0.5843 - accuracy: 0.6974
# Epoch 8/100
# 2340/2340 [==============================] - 0s 118us/step - loss: 0.5659 - accuracy: 0.7150
# Epoch 95/100
# 2340/2340 [==============================] - 0s 89us/step - loss: 0.1506 - accuracy: 0.9479
# Epoch 96/100
# 2340/2340 [==============================] - 0s 110us/step - loss: 0.1347 - accuracy: 0.9577
# Epoch 97/100
# 2340/2340 [==============================] - 0s 104us/step - loss: 0.1479 - accuracy: 0.9470
# Epoch 98/100
# 2340/2340 [==============================] - 0s 101us/step - loss: 0.1352 - accuracy: 0.9551
# Epoch 99/100
# 2340/2340 [==============================] - 0s 116us/step - loss: 0.1368 - accuracy: 0.9496
# Epoch 100/100
# 2340/2340 [==============================] - 0s 99us/step - loss: 0.1361 - accuracy: 0.9534

# %%
test_model(clf_edge, x_train_sel_edge, y_train_sample, 'train_edge')

# %%
test_model(clf_edge, x_test_sample, y_test_sample, 'test_edge')
# Out:
# Test on test_edge
# 0.0    300
# 1.0    286
# Name: Fault, dtype: int64
# Scenario : test_edge
# Pass/Fail : 300/286
#               precision    recall  f1-score   support
#
#         Pass       0.87      0.87      0.87       300
#         Fail       0.87      0.87      0.87       286
#
#     accuracy                           0.87       586
#    macro avg       0.87      0.87      0.87       586
# weighted avg       0.87      0.87      0.87       586

# %% [markdown]
# ## ML - CLFS edge

# %%
x_train_sel_edge = x_train_sample.loc[:, variables_edge]
x_test_sel_edge = x_test_sample.loc[:, variables_edge]
x_train_sel_edge.shape

# %%
# LogisticRegression
from sklearn.linear_model import LogisticRegression
if not load_saved_model:
    clf_lr = LogisticRegression().fit(x_train_sel_edge, y_train_sample)
    pickle.dump(clf_lr, open('model_lr.pkl', 'wb'))
else:
    clf_lr = pickle.load(open('model_lr.pkl', 'rb'))
    
test_model(clf_lr, x_test_sel_edge, y_test_sample, 'test_lr')

# %%
# Support vector machines
from sklearn import svm
if not load_saved_model:
    clf_svm = svm.SVC().fit(x_train_sel_edge, y_train_sample)
    pickle.dump(clf_svm, open('model_svm.pkl', 'wb'))
else:
    clf_svm = pickle.load(open('model_svm.pkl', 'rb'))

test_model(clf_svm, x_test_sel_edge, y_test_sample, 'test_svm')

# %%
# KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier

if not load_saved_model:
    clf_knn = KNeighborsClassifier(n_neighbors=3).fit(x_train_sel_edge, y_train_sample)
    pickle.dump(clf_knn, open('model_knn.pkl', 'wb'))
else:
    clf_knn = pickle.load(open('model_knn.pkl', 'rb'))

test_model(clf_knn, x_test_sel_edge, y_test_sample, 'test_knn')

# %%
# DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

if not load_saved_model:
    clf_dt = DecisionTreeClassifier().fit(x_train_sel_edge, y_train_sample)
    pickle.dump(clf_dt, open('model_dt.pkl', 'wb'))
else:
    clf_dt = pickle.load(open('model_dt.pkl', 'rb'))

test_model(clf_dt, x_test_sel_edge, y_test_sample, 'test_dt')

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB

if not load_saved_model:
    clf_nb = GaussianNB().fit(x_train_sel_edge, y_train_sample)
    pickle.dump(clf_nb, open('model_nb.pkl', 'wb'))
else:
    clf_nb = pickle.load(open('model_nb.pkl', 'rb'))

test_model(clf_nb, x_test_sel_edge, y_test_sample, 'test_nb')
