# %% [markdown]
# # Load libraries & parameters

# %%
# %matplotlib inline
import itertools as it
from sklearn.impute import SimpleImputer, KNNImputer
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.utils import to_categorical
from keras.utils import np_utils
import seaborn as sns
import scipy.cluster.hierarchy as spc
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from jmetal.algorithm.singleobjective.genetic_algorithm import GeneticAlgorithm
from jmetal.operator import BinaryTournamentSelection
from jmetal.operator.crossover import PMXCrossover
from jmetal.operator.mutation import PermutationSwapMutation
from jmetal.util.termination_criterion import StoppingByEvaluations
from jmetal.util.observer import PrintObjectivesObserver

# parameter
n_neighbors = 2
null_percentage = 0.5
test_size = 0.2
random_state = 1

k_best = 50
m_subsets = 5
assert k_best % m_subsets == 0
n_features = int(k_best/m_subsets)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load dataset

# %%
#  reading the data
data = pd.read_csv('uci-secom.csv')
data = data.drop(['Time'], axis = 1)

# getting the shape of the data
print(data.shape)
data.head()
# Out:
# (1567, 591)
#          0        1          2          3       4      5         6       7  \
# 0  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
#
#         8       9  ...       581     582     583     584      585     586  \
# 0  1.5005  0.0162  ...       NaN  0.5005  0.0118  0.0035   2.3630     NaN
# 1  1.4966 -0.0005  ...  208.2045  0.5019  0.0223  0.0055   4.4447  0.0096
# 2  1.4436  0.0041  ...   82.8602  0.4958  0.0157  0.0039   3.1745  0.0584
# 3  1.4882 -0.0124  ...   73.8432  0.4990  0.0103  0.0025   2.0544  0.0202
# 4  1.5031 -0.0031  ...       NaN  0.4800  0.4766  0.1045  99.3032  0.0202
#
#       587     588       589  Pass/Fail
# 0     NaN     NaN       NaN         -1
# 1  0.0201  0.0060  208.2045         -1
# 2  0.0484  0.0148   82.8602          1
# 3  0.0149  0.0044   73.8432         -1
# 4  0.0149  0.0044   73.8432         -1
#
# [5 rows x 591 columns]

# %%
data['Pass/Fail'].value_counts()
# Out:
# -1    1463
#  1     104
# Name: Pass/Fail, dtype: int64

# %%
data.describe()
# Out:
#                  0            1            2            3            4  \
# count  1561.000000  1560.000000  1553.000000  1553.000000  1553.000000
# mean   3014.452896  2495.850231  2200.547318  1396.376627     4.197013
# std      73.621787    80.407705    29.513152   441.691640    56.355540
# min    2743.240000  2158.750000  2060.660000     0.000000     0.681500
# 25%    2966.260000  2452.247500  2181.044400  1081.875800     1.017700
# 50%    3011.490000  2499.405000  2201.066700  1285.214400     1.316800
# 75%    3056.650000  2538.822500  2218.055500  1591.223500     1.525700
# max    3356.350000  2846.440000  2315.266700  3715.041700  1114.536600
#
#             5            6            7            8            9  ...  \
# count  1553.0  1553.000000  1558.000000  1565.000000  1565.000000  ...
# mean    100.0   101.112908     0.121822     1.462862    -0.000841  ...
# std       0.0     6.237214     0.008961     0.073897     0.015116  ...
# min     100.0    82.131100     0.000000     1.191000    -0.053400  ...
# 25%     100.0    97.920000     0.121100     1.411200    -0.010800  ...
# 50%     100.0   101.512200     0.122400     1.461600    -0.001300  ...
# 75%     100.0   104.586700     0.123800     1.516900     0.008400  ...
# max     100.0   129.252200     0.128600     1.656400     0.074900  ...
#
#               581          582          583          584          585  \
# count  618.000000  1566.000000  1566.000000  1566.000000  1566.000000
# mean    97.934373     0.500096     0.015318     0.003847     3.067826
# std     87.520966     0.003404     0.017180     0.003720     3.578033
# min      0.000000     0.477800     0.006000     0.001700     1.197500
# 25%     46.184900     0.497900     0.011600     0.003100     2.306500
# 50%     72.288900     0.500200     0.013800     0.003600     2.757650
# 75%    116.539150     0.502375     0.016500     0.004100     3.295175
# max    737.304800     0.509800     0.476600     0.104500    99.303200
#
#                586          587          588          589    Pass/Fail
# count  1566.000000  1566.000000  1566.000000  1566.000000  1567.000000
# mean      0.021458     0.016475     0.005283    99.670066    -0.867262
# std       0.012358     0.008808     0.002867    93.891919     0.498010
# min      -0.016900     0.003200     0.001000     0.000000    -1.000000
# 25%       0.013425     0.010600     0.003300    44.368600    -1.000000
# 50%       0.020500     0.014800     0.004600    71.900500    -1.000000
# 75%       0.027600     0.020300     0.006400   114.749700    -1.000000
# max       0.102800     0.079900     0.028600   737.304800     1.000000
#
# [8 rows x 591 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Data cleaning

# %%
def drop_constant_column(dataframe):
    for column in dataframe.columns:
        unique = dataframe[column].unique()
        unique = unique[~np.isnan(unique)]
        if len(unique) == 1:
            dataframe.drop(column,inplace=True,axis=1)
    return dataframe

# Drop columns with constant value
data = drop_constant_column(data)

# # print precentage of NaN value in each coloumn
# data.isnull().mean()*100.0

# Only keep columns with NaN values below 50%
data = data.loc[:, data.isnull().mean() < null_percentage]
data.head()
# Out:
#          0        1          2          3       4         6       7       8  \
# 0  3030.93  2564.00  2187.7333  1411.1265  1.3602   97.6133  0.1242  1.5005
# 1  3095.78  2465.14  2230.4222  1463.6606  0.8294  102.3433  0.1247  1.4966
# 2  2932.61  2559.94  2186.4111  1698.0172  1.5102   95.4878  0.1241  1.4436
# 3  2988.72  2479.90  2199.0333   909.7926  1.3204  104.2367  0.1217  1.4882
# 4  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.3967  0.1235  1.5031
#
#         9      10  ...      577     582     583     584      585     586  \
# 0  0.0162 -0.0034  ...  14.9509  0.5005  0.0118  0.0035   2.3630     NaN
# 1 -0.0005 -0.0148  ...  10.9003  0.5019  0.0223  0.0055   4.4447  0.0096
# 2  0.0041  0.0013  ...   9.2721  0.4958  0.0157  0.0039   3.1745  0.0584
# 3 -0.0124 -0.0033  ...   8.5831  0.4990  0.0103  0.0025   2.0544  0.0202
# 4 -0.0031 -0.0072  ...  10.9698  0.4800  0.4766  0.1045  99.3032  0.0202
#
#       587     588       589  Pass/Fail
# 0     NaN     NaN       NaN         -1
# 1  0.0201  0.0060  208.2045         -1
# 2  0.0484  0.0148   82.8602          1
# 3  0.0149  0.0044   73.8432         -1
# 4  0.0149  0.0044   73.8432         -1
#
# [5 rows x 447 columns]

# %% [markdown]
# ## Data imputation

# %%
# data.replace(np.nan, 0, inplace = True)
# imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = KNNImputer(n_neighbors=n_neighbors)
imputer.fit(data)
data = pd.DataFrame(imputer.transform(data), columns=data.columns)
print("Is there any null?", data.isnull().any().any())
data.head()
# Out:
# Is there any null? False
#          0        1          2          3       4         6       7       8  \
# 0  3030.93  2564.00  2187.7333  1411.1265  1.3602   97.6133  0.1242  1.5005
# 1  3095.78  2465.14  2230.4222  1463.6606  0.8294  102.3433  0.1247  1.4966
# 2  2932.61  2559.94  2186.4111  1698.0172  1.5102   95.4878  0.1241  1.4436
# 3  2988.72  2479.90  2199.0333   909.7926  1.3204  104.2367  0.1217  1.4882
# 4  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.3967  0.1235  1.5031
#
#         9      10  ...      577     582     583     584      585     586  \
# 0  0.0162 -0.0034  ...  14.9509  0.5005  0.0118  0.0035   2.3630  0.0148
# 1 -0.0005 -0.0148  ...  10.9003  0.5019  0.0223  0.0055   4.4447  0.0096
# 2  0.0041  0.0013  ...   9.2721  0.4958  0.0157  0.0039   3.1745  0.0584
# 3 -0.0124 -0.0033  ...   8.5831  0.4990  0.0103  0.0025   2.0544  0.0202
# 4 -0.0031 -0.0072  ...  10.9698  0.4800  0.4766  0.1045  99.3032  0.0202
#
#       587     588       589  Pass/Fail
# 0  0.0119  0.0037   75.0808       -1.0
# 1  0.0201  0.0060  208.2045       -1.0
# 2  0.0484  0.0148   82.8602        1.0
# 3  0.0149  0.0044   73.8432       -1.0
# 4  0.0149  0.0044   73.8432       -1.0
#
# [5 rows x 447 columns]

# %% [markdown]
# ## Dataset splitting

# %%
x = data.iloc[:, 0:-1]
y = data.iloc[:, -1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = test_size, random_state = random_state)

# %% [markdown]
# # Edge deployment

# %% [markdown]
# ## Select k features based on the importances

# %%
model = ExtraTreesClassifier()
model.fit(x,y)
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
k_best_features = feat_importances.nlargest(k_best)
k_best_features.plot(kind='barh')
plt.figure(figsize=(20,20))
plt.show()

# %%
k_best_features_idx = k_best_features.index
data_importance = data.loc[:, k_best_features_idx]
data_importance.head()
# Out:
#         64       59     348     437       65  166       38    205     571  \
# 0  21.7264  -1.7264  0.0215  3.1136  29.5367  2.0  86.9555   8.64  2.1113
# 1  19.1927   0.8073  0.0142  3.2153  27.6301  2.2  87.5241   8.96  2.4335
# 2  16.1755  23.8245  0.0105  3.1281  24.2829  2.1  84.7327  13.30  2.0293
# 3  15.6209  24.3791  0.0407  2.7013  23.4736  1.7  86.6867   9.56  2.0253
# 4  32.2945 -12.2945  0.0246  6.2069  44.1498  3.9  86.1468   9.09  2.0275
#
#            2  ...  387     405     152     107        68      434     239  \
# 0  2187.7333  ...  0.0  0.0151  0.4734 -0.2468  148.6009  10.0503  0.0040
# 1  2230.4222  ...  0.0  0.0120  0.5666  0.0772  154.3709   8.6336  0.0036
# 2  2186.4111  ...  0.0  0.0190  0.4909 -0.0301  145.8000  14.2503  0.0040
# 3  2199.0333  ...  0.0  0.0155  1.3029 -0.0483  147.6545   5.1760  0.0040
# 4  2233.3667  ...  0.0  0.0165  0.4434 -0.0799  146.6636  11.4064  0.0031
#
#         139      95      148
# 0  350.6710  0.0003  12.2566
# 1  219.7679  0.0001  12.3319
# 2  306.0380  0.0002   8.2660
# 3  162.4320  0.0002  13.2651
# 4  296.3030 -0.0001  14.2354
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Generate m subsets of n features based on the correlation

# %%
#get correlations of each features in dataset
corrmat = abs(data_importance.corr())
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(abs(data_importance[top_corr_features].corr()),annot=True,cmap="RdYlGn")

# %%
import math
import random
import re
from jmetal.core.problem import PermutationProblem
from jmetal.core.solution import PermutationSolution

# Feature correlation selection
class FCS(PermutationProblem):

    def __init__(self, correlation, variables, subsets):
        super(FCS, self).__init__()

        self.correlation = correlation
        self.subsets = subsets
        self.features = int(variables/subsets)

        # Minimization to find most independent between variable 
        self.obj_directions = [self.MINIMIZE]
        self.number_of_variables = variables
        self.number_of_objectives = 1
        self.number_of_constraints = 0

    def evaluate(self, solution: PermutationSolution) -> PermutationSolution:
        fitness = 0

        for i in range(self.subsets):

          end = self.features*(i+1)
          start = end - self.features

          comb = list(it.combinations(solution.variables[start:end-1], 2))

          for j in comb:
              fitness += self.correlation[j[0]][j[1]]

          solution.objectives[0] = fitness

        return solution

    def create_solution(self) -> PermutationSolution:
        new_solution = PermutationSolution(number_of_variables=self.number_of_variables,
                                           number_of_objectives=self.number_of_objectives)
        new_solution.variables = random.sample(range(self.number_of_variables), k=self.number_of_variables)

        return new_solution
    
    def get_name(self):
        return 'Feature correlation selection'

# %%
problem = FCS(abs(corrmat.values), k_best, m_subsets)

algorithm = GeneticAlgorithm(
        problem=problem,
        population_size=100,
        offspring_population_size=100,
        mutation=PermutationSwapMutation(1.0 / k_best),
        crossover=PMXCrossover(0.8),
        selection=BinaryTournamentSelection(),
        termination_criterion=StoppingByEvaluations(max=200000)
    )

algorithm.observable.register(observer=PrintObjectivesObserver(10000))

algorithm.run()
result = algorithm.get_result()

print('Algorithm: {}'.format(algorithm.get_name()))
print('Problem: {}'.format(problem.get_name()))
print('Solution: {}'.format(result.variables))
print('Fitness: {}'.format(result.objectives[0]))
print('Computing time: {}'.format(algorithm.total_computing_time))
# Out:
# 2020-01-02 17:42:22,208 [MainThread  ] [INFO ]  Evaluations: 10000. fitness: [4.02456343385481]
# 2020-01-02 17:42:24,209 [MainThread  ] [INFO ]  Evaluations: 20000. fitness: [4.005417069093939]
# 2020-01-02 17:42:26,173 [MainThread  ] [INFO ]  Evaluations: 30000. fitness: [3.8841364095297304]
# 2020-01-02 17:42:28,200 [MainThread  ] [INFO ]  Evaluations: 40000. fitness: [3.8489423813864696]
# 2020-01-02 17:42:30,107 [MainThread  ] [INFO ]  Evaluations: 50000. fitness: [3.760558420059743]
# 2020-01-02 17:42:32,051 [MainThread  ] [INFO ]  Evaluations: 60000. fitness: [3.6720971138227654]
# 2020-01-02 17:42:33,969 [MainThread  ] [INFO ]  Evaluations: 70000. fitness: [3.52416395462554]
# 2020-01-02 17:42:35,952 [MainThread  ] [INFO ]  Evaluations: 80000. fitness: [3.4725249053309004]
# 2020-01-02 17:42:37,970 [MainThread  ] [INFO ]  Evaluations: 90000. fitness: [3.457666425921589]
# 2020-01-02 17:42:39,924 [MainThread  ] [INFO ]  Evaluations: 100000. fitness: [3.4478183587266105]
# 2020-01-02 17:42:41,814 [MainThread  ] [INFO ]  Evaluations: 110000. fitness: [3.3865857117262284]
# 2020-01-02 17:42:43,774 [MainThread  ] [INFO ]  Evaluations: 120000. fitness: [3.321200394894846]
# 2020-01-02 17:42:45,673 [MainThread  ] [INFO ]  Evaluations: 130000. fitness: [3.232373534299719]
# 2020-01-02 17:42:47,566 [MainThread  ] [INFO ]  Evaluations: 140000. fitness: [3.2068071365528232]
# 2020-01-02 17:42:49,460 [MainThread  ] [INFO ]  Evaluations: 150000. fitness: [3.2068071365528232]
# 2020-01-02 17:42:51,453 [MainThread  ] [INFO ]  Evaluations: 160000. fitness: [3.2068071365528232]
# 2020-01-02 17:42:53,368 [MainThread  ] [INFO ]  Evaluations: 170000. fitness: [3.206807136552823]
# 2020-01-02 17:42:55,256 [MainThread  ] [INFO ]  Evaluations: 180000. fitness: [3.206224681694048]
# 2020-01-02 17:42:57,139 [MainThread  ] [INFO ]  Evaluations: 190000. fitness: [3.206224681694048]
# 2020-01-02 17:42:59,067 [MainThread  ] [INFO ]  Evaluations: 200000. fitness: [3.206224681694048]
# Algorithm: Genetic algorithm
# Problem: Feature correlation selection
# Solution: [14, 18, 47, 49, 7, 33, 0, 29, 28, 10, 42, 16, 3, 46, 11, 40, 12, 41, 34, 26, 23, 21, 22, 27, 44, 48, 24, 4, 35, 6, 19, 13, 31, 30, 32, 39, 20, 17, 43, 1, 2, 8, 25, 37, 36, 5, 38, 9, 15, 45]
# Fitness: 3.206224681694048
# Computing time: 38.87007808685303

# %%
feature_subsets = []
subset = []
for i in result.variables:
    subset.append(i)
    if len(subset) == n_features:
        feature_subsets.append(subset)
        subset = []
        
feature_subsets
# Out:
# [[14, 18, 47, 49, 7, 33, 0, 29, 28, 10],
#  [42, 16, 3, 46, 11, 40, 12, 41, 34, 26],
#  [23, 21, 22, 27, 44, 48, 24, 4, 35, 6],
#  [19, 13, 31, 30, 32, 39, 20, 17, 43, 1],
#  [2, 8, 25, 37, 36, 5, 38, 9, 15, 45]]
